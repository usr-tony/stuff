# %%
import pandas as pd
from config import rds, local
from lambda_function import helpers
from sqlalchemy import create_engine
from ast import literal_eval
from seek import scrape
import sqlite3
import boto3
from time import time
import requests
import json
import io
from datetime import timedelta, datetime
import numpy as np

# %%
res = requests.post('https://g0ud4ex9ui.execute-api.ap-southeast-2.amazonaws.com/jobs', json={'by': 'sector'})
res.json()
