# %%
import pandas as pd
from config import rds, local
from sqlalchemy import create_engine
from ast import literal_eval
from seek import scrape
import sqlite3
import boto3
from time import time
import requests
import json
import io
from datetime import timedelta, datetime
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/tony/programming/jobs/lambda_test.ipynb Cell 1 in <cell line: 7>()
#       <a href='vscode-notebook-cell:/Users/tony/programming/jobs/lambda_test.ipynb#W0sZmlsZQ%3D%3D?line=4'>5</a> from seek import scrape
#       <a href='vscode-notebook-cell:/Users/tony/programming/jobs/lambda_test.ipynb#W0sZmlsZQ%3D%3D?line=5'>6</a> import sqlite3
# ----> <a href='vscode-notebook-cell:/Users/tony/programming/jobs/lambda_test.ipynb#W0sZmlsZQ%3D%3D?line=6'>7</a> import boto3
#       <a href='vscode-notebook-cell:/Users/tony/programming/jobs/lambda_test.ipynb#W0sZmlsZQ%3D%3D?line=7'>8</a> from time import time
#       <a href='vscode-notebook-cell:/Users/tony/programming/jobs/lambda_test.ipynb#W0sZmlsZQ%3D%3D?line=8'>9</a> import requests
#
# ModuleNotFoundError: No module named 'boto3'

# %%
res = requests.post('https://g0ud4ex9ui.execute-api.ap-southeast-2.amazonaws.com/jobs', json={'by': 'sector'})
res.json()
